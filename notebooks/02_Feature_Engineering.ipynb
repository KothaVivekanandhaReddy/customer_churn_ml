# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.preprocess import (
    load_data,
    clean_data,
    handle_missing_values
)

df = load_data("../data/customer_churn_1M.csv")

df = clean_data(df)

df = handle_missing_values(df)

df.head()
# Out:
#    age  gender  annual_income    education marital_status  dependents  tenure  \
# 0   43  Female       55085.25      college        married           1       2
# 1   18    Male       60786.11       master        married           1      22
# 2   38  Female       73184.32  high_school        widowed           0       3
# 3   44    Male       40923.78  high_school        married           1       6
# 4   45  Female       36400.94     bachelor         single           0       9
#
#    contract    payment_method paperless_billing  ...  has_streaming_movies  \
# 0  two_year  electronic_check               Yes  ...                     1
# 1  one_year     bank_transfer               Yes  ...                     1
# 2  two_year       credit_card                No  ...                     0
# 3  two_year     bank_transfer               Yes  ...                     1
# 4  two_year       credit_card               Yes  ...                     1
#
#    customer_satisfaction  num_complaints  num_service_calls  late_payments  \
# 0                    9.0             0.0                  0              0
# 1                    7.0             0.0                  3              1
# 2                    6.0             1.0                  1              0
# 3                    5.0             2.0                  2              1
# 4                    8.0             1.0                  1              0
#
#    avg_monthly_gb  days_since_last_interaction  credit_score  churn  \
# 0          109.63                           16         680.0      0
# 1           63.25                          134         585.0      0
# 2           47.77                           11         632.0      0
# 3           50.82                            6         569.0      0
# 4           16.74                           18         657.0      0
#
#    days_since_signup
# 0               1272
# 1               1605
# 2               1006
# 3               1440
# 4               1276
#
# [5 rows x 31 columns]

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# age                            0
# has_online_security            0
# churn                          0
# credit_score                   0
# days_since_last_interaction    0
# avg_monthly_gb                 0
# late_payments                  0
# num_service_calls              0
# num_complaints                 0
# customer_satisfaction          0
# dtype: int64

# %%
df["days_since_signup"].head()
# Out:
# 0    1272
# 1    1605
# 2    1006
# 3    1440
# 4    1276
# Name: days_since_signup, dtype: int64
